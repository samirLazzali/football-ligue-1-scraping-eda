# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn
from scipy.stats import poisson,skellam
import os

# %matplotlib inline
plt.style.use('seaborn-whitegrid') # theme
plt.rcParams['figure.figsize'] = (12,8) # taille des figures
extract = pd.read_csv("/home/sam/Documents/cours/python/football-ligue-1-scraping-eda-master/exctract.csv")
print(extract.shape)
extract.head()
# 13 	1 	2019-10-19 19:00:00 	Saturday 	19:00 	1.62 	6.20 	3.77 	AWAY 	AWAY 	0 	0 	1 	2019/2020 	Angers 	Brest
# Out:
# (5956, 15)
#    bmkr_loss                 date       day  hours  odds_a  odds_b  odds_draw  \
# 0          0  2019-10-27 20:00:00    Sunday  20:00    1.20   13.07       7.39
# 1          0  2019-10-27 16:00:00    Sunday  16:00    2.28    3.39       3.21
# 2          0  2019-10-27 14:00:00    Sunday  14:00    1.85    4.46       3.57
# 3          0  2019-10-26 19:00:00  Saturday  19:00    2.36    3.19       3.27
# 4          0  2019-10-26 19:00:00  Saturday  19:00    1.43    7.80       4.52
#
#   outcome_effectif outcome_odds  prediction_odds  score_a  score_b     season  \
# 0             HOME         DRAW                1        4        0  2019/2020
# 1             DRAW         AWAY                0        2        2  2019/2020
# 2             HOME         AWAY                1        3        2  2019/2020
# 3             HOME         DRAW                1        2        0  2019/2020
# 4             HOME         AWAY                1        2        0  2019/2020
#
# ...

# %%
extract.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8); # ; avoid having the matplotlib verbose informations

# %%
import seaborn as sns
for i in range(0, len(extract.columns), 5):
    sns.pairplot(data=extract,
                x_vars=extract.columns[i:i+5],
                y_vars=['bmkr_loss'])

# %%
#https://www.kaggle.com/ekami66/detailed-exploratory-data-analysis-with-python
# Out:
#   File "<ipython-input-26-96dbae8c74b3>", line 1
#     https://www.kaggle.com/ekami66/detailed-exploratory-data-analysis-with-python
#            ^
# SyntaxError: invalid syntax

# %%
extract1 = extract[['bmkr_loss', 'day','hours']]
#extract1.groupby(['hours','day']).mean()
# extract[(extract.day == 'Friday') & (extract.hours == '16:00')]
#extract1.groupby(['hours']).mean()
print (extract.shape)
# Out:
# (5956, 15)

# %%
#plt.plot(extract1['day'], extract['bmkr_loss'])
extract1_count = extract1.groupby(['day','hours']).count()
extract1_count = extract1_count[(extract1_count['bmkr_loss'] != 0)]
extract1_count.plot()
#extract1.plot(kind="bar")
#extract1[extract1.day == 'Friday'].plot(kind="bar")

# %%
#plt.plot(extract1['day'], extract['bmkr_loss'])
extract1_mean = extract1.groupby(['day','hours']).mean()
extract1_mean = extract1_mean[(extract1_mean['bmkr_loss'] != 0)]
extract1_mean.plot()
#extract1.plot(kind="bar")
#extract1[extract1.day == 'Friday'].plot(kind="bar")
